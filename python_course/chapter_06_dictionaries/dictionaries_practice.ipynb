# %% [markdown]
# # Chapter 6: Dictionaries - Key-Value Pairs - Practice Notebook
#
# Welcome to Chapter 6! In this session, you'll master **dictionaries** - Python's powerful key-value data structure.
#
# By the end, you'll be able to:
# - Create and use dictionaries
# - Access and modify dictionary values
# - Use dictionary methods effectively
# - Iterate through dictionaries
# - Understand when to use dictionaries vs lists
# - Build real-world applications with dictionaries
#
# ---

# %% [markdown]
# ## Part 1: Understanding Dictionaries
#
# A **dictionary** stores data as **key-value pairs**. Think of it like a real dictionary where you look up a word (key) to find its definition (value).

# %%
# Real-world analogy: A contact book
# Name (key) → Phone Number (value)

contacts = {
    "Alice": "555-1234",
    "Bob": "555-5678",
    "Carol": "555-9012"
}

print(contacts)

# %%
# Why use dictionaries instead of lists?
# Lists use numeric indices (0, 1, 2...)
# Dictionaries use meaningful keys ("name", "age", "email"...)

# List approach - hard to remember what each position means
student_list = ["Ahmed", 20, "Cairo", "CS"]
print("Name:", student_list[0])  # Which index was name again?

# Dictionary approach - clear and readable!
student_dict = {
    "name": "Ahmed",
    "age": 20,
    "city": "Cairo",
    "major": "CS"
}
print("Name:", student_dict["name"])  # Much clearer!

# %% [markdown]
# ---
# ## Part 2: Creating Dictionaries
#
# There are several ways to create dictionaries in Python.

# %% [markdown]
# ### Empty Dictionaries

# %%
# Method 1: Using curly braces
empty_dict1 = {}
print("Empty dict 1:", empty_dict1)

# Method 2: Using dict() function
empty_dict2 = dict()
print("Empty dict 2:", empty_dict2)

print("Type:", type(empty_dict1))

# %% [markdown]
# ### Dictionaries with Data

# %%
# Creating a dictionary with initial data
person = {
    "name": "Sarah",
    "age": 25,
    "city": "New York",
    "occupation": "Engineer"
}

print(person)

# %%
# Dictionary values can be different types
student = {
    "name": "Ali",           # String
    "age": 20,               # Integer
    "gpa": 3.8,              # Float
    "enrolled": True,        # Boolean
    "courses": ["Math", "CS", "Physics"]  # List
}

print(student)
print(f"\nName: {student['name']}")
print(f"Courses: {student['courses']}")

# %%
# Using dict() constructor with keyword arguments
car = dict(brand="Toyota", model="Camry", year=2022, color="Blue")
print(car)

# %% [markdown]
# ### Exercise 2.1: Create Your Own Dictionaries
# Create the following dictionaries:
# 1. A dictionary representing your favorite book (title, author, pages, year)
# 2. A dictionary for a product in a store (name, price, quantity, category)
# 3. A dictionary about yourself (at least 5 key-value pairs)

# %%
# Write your code here

# %% [markdown]
# ---
# ## Part 3: Accessing and Modifying Values
#
# Use keys to access and change values in dictionaries.

# %% [markdown]
# ### Accessing Values

# %%
# Using square brackets []
student = {
    "name": "Maria",
    "age": 22,
    "major": "Biology"
}

print("Name:", student["name"])
print("Age:", student["age"])
print("Major:", student["major"])

# %%
# What happens if a key doesn't exist?
# Uncomment the line below to see the error:
# print(student["email"])  # KeyError: 'email'

# %%
# Using get() method - SAFER!
student = {"name": "Maria", "age": 22, "major": "Biology"}

# If key exists, returns the value
print("Name:", student.get("name"))

# If key doesn't exist, returns None (no error!)
print("Email:", student.get("email"))

# You can specify a default value
print("Email:", student.get("email", "Not provided"))
print("Phone:", student.get("phone", "No phone number"))

# %% [markdown]
# ### Modifying Values

# %%
# Change an existing value
person = {"name": "John", "age": 25, "city": "Boston"}
print("Before:", person)

person["age"] = 26  # Update age
person["city"] = "New York"  # Update city
print("After:", person)

# %% [markdown]
# ### Adding New Key-Value Pairs

# %%
# Add new keys by assigning values
person = {"name": "Emma", "age": 28}
print("Before:", person)

person["city"] = "London"  # Add new key
person["job"] = "Designer"  # Add another key
print("After:", person)

# %% [markdown]
# ### Removing Items

# %%
# Using del keyword
person = {"name": "Tom", "age": 30, "city": "Paris", "job": "Teacher"}
print("Before:", person)

del person["job"]  # Remove the 'job' key
print("After del:", person)

# %%
# Using pop() - removes and returns the value
person = {"name": "Tom", "age": 30, "city": "Paris"}
print("Before:", person)

city = person.pop("city")  # Remove and get the value
print(f"Removed city: {city}")
print("After pop:", person)

# %%
# Using clear() - removes all items
person = {"name": "Tom", "age": 30, "city": "Paris"}
print("Before:", person)

person.clear()
print("After clear:", person)

# %% [markdown]
# ### Exercise 3.1: Modify a Dictionary
# Start with this dictionary and make the following changes:
# 1. Change the price to 899.99
# 2. Add a new key "color" with value "Silver"
# 3. Add a new key "in_stock" with value True
# 4. Remove the "brand" key
# 5. Print the final dictionary

# %%
product = {
    "name": "Laptop",
    "brand": "Dell",
    "price": 999.99
}

# Write your code here

# %% [markdown]
# ---
# ## Part 4: Dictionary Methods
#
# Dictionaries have many useful built-in methods.

# %% [markdown]
# ### keys() - Get all keys

# %%
student = {"name": "Alice", "age": 20, "major": "CS", "gpa": 3.8}

# Get all keys
keys = student.keys()
print("Keys:", keys)
print("Type:", type(keys))

# Convert to list if needed
keys_list = list(student.keys())
print("Keys as list:", keys_list)

# %% [markdown]
# ### values() - Get all values

# %%
student = {"name": "Alice", "age": 20, "major": "CS", "gpa": 3.8}

# Get all values
values = student.values()
print("Values:", values)

# Convert to list
values_list = list(student.values())
print("Values as list:", values_list)

# %% [markdown]
# ### items() - Get key-value pairs

# %%
student = {"name": "Alice", "age": 20, "major": "CS", "gpa": 3.8}

# Get all key-value pairs as tuples
items = student.items()
print("Items:", items)

# Convert to list of tuples
items_list = list(student.items())
print("Items as list:", items_list)

# %% [markdown]
# ### update() - Add multiple items at once

# %%
student = {"name": "Bob", "age": 21}
print("Before:", student)

# Add multiple key-value pairs
student.update({"major": "Physics", "gpa": 3.5, "city": "Boston"})
print("After update:", student)

# update() also modifies existing keys
student.update({"age": 22, "gpa": 3.7})
print("After second update:", student)

# %% [markdown]
# ### Checking if a Key Exists

# %%
# Using 'in' operator
student = {"name": "Carol", "age": 23, "major": "Math"}

print("Is 'name' in dictionary?", "name" in student)
print("Is 'email' in dictionary?", "email" in student)
print("Is 'age' NOT in dictionary?", "age" not in student)

# Use in conditional statements
if "email" in student:
    print("Email:", student["email"])
else:
    print("Email not found")

# %% [markdown]
# ### Getting Dictionary Length

# %%
# len() returns the number of key-value pairs
student = {"name": "David", "age": 24, "major": "Chemistry", "gpa": 3.6}

print("Number of items:", len(student))

empty = {}
print("Empty dictionary length:", len(empty))

# %% [markdown]
# ### Exercise 4.1: Dictionary Methods Practice
# Given the dictionary below:
# 1. Get and print all the keys
# 2. Get and print all the values
# 3. Check if "stock" is in the dictionary
# 4. Use update() to add two new items: "supplier": "TechCorp" and "warranty": 2
# 5. Print the total number of items in the dictionary

# %%
product = {
    "name": "Mouse",
    "price": 29.99,
    "category": "Electronics"
}

# Write your code here

# %% [markdown]
# ---
# ## Part 5: Iterating Through Dictionaries
#
# There are several ways to loop through dictionaries.

# %% [markdown]
# ### Loop Through Keys

# %%
# Default: iterating through a dictionary loops through keys
student = {"name": "Emma", "age": 21, "major": "Art"}

print("Keys:")
for key in student:
    print(f"  {key}")

# %%
# Explicitly using .keys()
student = {"name": "Emma", "age": 21, "major": "Art"}

print("Keys (explicit):")
for key in student.keys():
    print(f"  {key}")

# %% [markdown]
# ### Loop Through Values

# %%
# Using .values()
student = {"name": "Frank", "age": 22, "major": "Music"}

print("Values:")
for value in student.values():
    print(f"  {value}")

# %% [markdown]
# ### Loop Through Key-Value Pairs (Most Common!)

# %%
# Using .items() - best way to access both key and value!
student = {"name": "Grace", "age": 20, "major": "History", "gpa": 3.9}

print("Key-Value Pairs:")
for key, value in student.items():
    print(f"  {key}: {value}")

# %%
# Practical example: Display formatted information
person = {
    "name": "Ahmed Hassan",
    "age": 28,
    "city": "Dubai",
    "occupation": "Data Scientist",
    "salary": 85000
}

print("=" * 40)
print("PERSON INFORMATION")
print("=" * 40)
for key, value in person.items():
    # Capitalize and format the key
    formatted_key = key.replace("_", " ").title()
    print(f"{formatted_key:15s}: {value}")
print("=" * 40)

# %% [markdown]
# ### Exercise 5.1: Iteration Practice
# Using the prices dictionary below:
# 1. Loop through and print all product names
# 2. Loop through and print all prices
# 3. Loop through and print each product with its price in the format: "Apple costs $1.50"
# 4. Calculate and print the total cost of all products

# %%
prices = {
    "Apple": 1.50,
    "Banana": 0.75,
    "Orange": 1.25,
    "Mango": 2.00,
    "Grape": 3.50
}

# Write your code here

# %% [markdown]
# ---
# ## Part 6: Dictionary vs List
#
# Understanding when to use dictionaries vs lists is important!

# %%
# Lists: Use for ordered collections of similar items
shopping_list = ["milk", "bread", "eggs", "butter"]
scores = [85, 90, 78, 92, 88]

print("Shopping list:", shopping_list)
print("First item:", shopping_list[0])
print("Third score:", scores[2])

# %%
# Dictionaries: Use for labeled data with different attributes
student = {
    "name": "John",
    "age": 20,
    "major": "CS",
    "gpa": 3.7,
    "courses": ["Math", "Physics", "Programming"]
}

print("Student info:", student)
print("Name:", student["name"])  # Clear what we're accessing
print("Courses:", student["courses"])

# %%
# Comparison: Storing multiple students

# Using lists (harder to read and maintain)
student1 = ["Alice", 20, "Biology", 3.8]
student2 = ["Bob", 21, "Chemistry", 3.5]
# What does index 2 represent? Hard to remember!

# Using dictionaries (clear and self-documenting)
student1 = {"name": "Alice", "age": 20, "major": "Biology", "gpa": 3.8}
student2 = {"name": "Bob", "age": 21, "major": "Chemistry", "gpa": 3.5}
# Much clearer!

print(f"{student1['name']} is {student1['age']} years old")

# %% [markdown]
# ### When to Use What?
#
# **Use Lists when:**
# - You have a collection of similar items
# - Order matters
# - You need to access items by position
# - Examples: shopping items, test scores, temperatures
#
# **Use Dictionaries when:**
# - You have labeled/named data
# - You need to look up values by meaningful keys
# - You're storing attributes of an object
# - Examples: person info, product details, settings

# %% [markdown]
# ### Exercise 6.1: Choose the Right Structure
# For each scenario below, decide if you would use a list or dictionary and create it:
#
# 1. Store the days of the week
# 2. Store a person's name, email, and phone number
# 3. Store the top 5 movie ratings
# 4. Store a car's make, model, year, and color

# %%
# Write your code here

# %% [markdown]
# ---
# ## Part 7: Nested Dictionaries
#
# Dictionaries can contain other dictionaries (or lists)!

# %%
# Simple nested dictionary
student = {
    "name": "Lisa",
    "age": 21,
    "grades": {
        "math": 90,
        "english": 85,
        "science": 92
    }
}

# Access nested values
print("Student name:", student["name"])
print("Math grade:", student["grades"]["math"])
print("English grade:", student["grades"]["english"])

# %%
# Multiple students with nested information
students = {
    "student1": {
        "name": "Alice",
        "age": 20,
        "major": "CS"
    },
    "student2": {
        "name": "Bob",
        "age": 21,
        "major": "Math"
    },
    "student3": {
        "name": "Carol",
        "age": 22,
        "major": "Physics"
    }
}

# Access specific student
print("Student 1 name:", students["student1"]["name"])
print("Student 2 major:", students["student2"]["major"])

# Loop through all students
print("\nAll Students:")
for student_id, info in students.items():
    print(f"\n{student_id}:")
    for key, value in info.items():
        print(f"  {key}: {value}")

# %%
# Dictionary with lists
company = {
    "name": "Tech Solutions",
    "employees": ["Alice", "Bob", "Carol", "David"],
    "departments": ["Engineering", "Sales", "HR"],
    "location": {
        "city": "San Francisco",
        "state": "CA",
        "zip": "94102"
    }
}

print("Company:", company["name"])
print("First employee:", company["employees"][0])
print("City:", company["location"]["city"])
print("All employees:", company["employees"])

# %% [markdown]
# ### Exercise 7.1: Create a Nested Dictionary
# Create a nested dictionary representing a school with at least 3 students. Each student should have:
# - name
# - age
# - grades (as a nested dictionary with at least 3 subjects)
#
# Then:
# 1. Print one student's information
# 2. Print a specific grade for a specific student
# 3. Loop through all students and print their names

# %%
# Write your code here

# %% [markdown]
# ---
# ## Part 8: Real-World Applications
#
# Let's build practical programs using dictionaries!

# %% [markdown]
# ### Application 1: Phone Book

# %%
# Simple phone book application
phone_book = {
    "Alice": "555-1234",
    "Bob": "555-5678",
    "Carol": "555-9012",
    "David": "555-3456"
}

# Look up a contact
name = input("Enter name to look up: ")

if name in phone_book:
    print(f"{name}'s phone number: {phone_book[name]}")
else:
    print(f"{name} not found in phone book")

# Display all contacts
print("\n" + "=" * 30)
print("ALL CONTACTS")
print("=" * 30)
for name, phone in phone_book.items():
    print(f"{name:15s}: {phone}")

# %% [markdown]
# ### Application 2: Student Grade Tracker

# %%
# Student with multiple subject grades
student = {
    "name": "Ahmed",
    "student_id": "S12345",
    "grades": {
        "Mathematics": 88,
        "Physics": 92,
        "Chemistry": 85,
        "English": 90,
        "Computer Science": 95
    }
}

# Display student report
print("=" * 50)
print(f"STUDENT GRADE REPORT")
print("=" * 50)
print(f"Name: {student['name']}")
print(f"Student ID: {student['student_id']}")
print("\nGrades:")
print("-" * 50)

total = 0
for subject, grade in student["grades"].items():
    print(f"{subject:20s}: {grade}")
    total += grade

average = total / len(student["grades"])
print("-" * 50)
print(f"Average Grade: {average:.2f}")
print("=" * 50)

# %% [markdown]
# ### Application 3: Inventory Management System

# %%
# Store inventory
inventory = {
    "Laptop": {"price": 999.99, "quantity": 15, "category": "Electronics"},
    "Mouse": {"price": 25.99, "quantity": 50, "category": "Electronics"},
    "Keyboard": {"price": 79.99, "quantity": 30, "category": "Electronics"},
    "Monitor": {"price": 299.99, "quantity": 20, "category": "Electronics"},
    "Headphones": {"price": 149.99, "quantity": 25, "category": "Audio"}
}

# Display inventory
print("=" * 70)
print("INVENTORY REPORT")
print("=" * 70)
print(f"{'Product':<15} {'Price':>10} {'Quantity':>10} {'Value':>12} {'Category':<15}")
print("-" * 70)

total_value = 0
for product, details in inventory.items():
    value = details["price"] * details["quantity"]
    total_value += value
    print(f"{product:<15} ${details['price']:>9.2f} {details['quantity']:>10} ${value:>11.2f} {details['category']:<15}")

print("=" * 70)
print(f"Total Inventory Value: ${total_value:,.2f}")
print(f"Total Products: {len(inventory)}")
print("=" * 70)

# %% [markdown]
# ### Application 4: Word Counter

# %%
# Count word frequency in a sentence
text = "python is amazing and python is powerful and python is fun"

# Split text into words
words = text.lower().split()

# Count each word
word_count = {}
for word in words:
    if word in word_count:
        word_count[word] += 1
    else:
        word_count[word] = 1

# Display results
print("Word Frequency:")
for word, count in word_count.items():
    print(f"  {word}: {count}")

# Find most common word
most_common = max(word_count, key=word_count.get)
print(f"\nMost common word: '{most_common}' appears {word_count[most_common]} times")

# %% [markdown]
# ---
# ## 🎯 Challenge Exercises
#
# Put all your dictionary skills to the test!

# %% [markdown]
# ### Challenge 1: Interactive Contact Manager
# Create a contact manager that allows the user to:
# - Add a new contact (name and phone)
# - Look up a contact
# - Delete a contact
# - Display all contacts
# - Exit
#
# Use a loop to keep the program running until the user chooses to exit.

# %%
# Write your code here

# %% [markdown]
# ### Challenge 2: Student Database
# Create a program that:
# - Stores information for at least 3 students (name, age, grades for 3 subjects)
# - Calculates each student's average grade
# - Finds and displays the student with the highest average
# - Displays all students with their averages

# %%
# Write your code here

# %% [markdown]
# ### Challenge 3: Product Catalog
# Create a shopping catalog where:
# - Each product has: name, price, category, and stock quantity
# - Calculate total inventory value
# - Find all products in a specific category
# - Find products that are low in stock (quantity < 10)
# - Display the most expensive product

# %%
# Write your code here

# %% [markdown]
# ### Challenge 4: Dictionary Merge
# Write a function that takes two dictionaries and merges them. If a key exists in both dictionaries, add their values together.

# %%
def merge_dictionaries(dict1, dict2):
    # Write your code here
    pass

# Test your function
inventory1 = {"apples": 10, "bananas": 5, "oranges": 8}
inventory2 = {"bananas": 3, "oranges": 2, "grapes": 15}

# Should give: {"apples": 10, "bananas": 8, "oranges": 10, "grapes": 15}
result = merge_dictionaries(inventory1, inventory2)
print(result)

# %% [markdown]
# ### Challenge 5: Reverse Dictionary
# Create a function that reverses a dictionary (swaps keys and values).
# Example: {"a": 1, "b": 2} becomes {1: "a", 2: "b"}

# %%
def reverse_dictionary(d):
    # Write your code here
    pass

# Test your function
original = {"name": "Alice", "age": 25, "city": "NYC"}
reversed_dict = reverse_dictionary(original)
print(reversed_dict)

# %% [markdown]
# ### Challenge 6: Create Your Own Application!
# Design and build your own dictionary-based application. Ideas:
# - Restaurant menu with prices and descriptions
# - Quiz game with questions and answers
# - Movie database with ratings and genres
# - Recipe book with ingredients
# - Employee management system
#
# Be creative!

# %%
# Your creative application here!

# %% [markdown]
# ---
# ## 🎉 Congratulations!
#
# You've completed Chapter 6! You now know:
# - ✅ What dictionaries are and why they're powerful
# - ✅ How to create dictionaries (empty and with data)
# - ✅ How to access and modify values using keys
# - ✅ All the essential dictionary methods (keys(), values(), items(), get(), pop(), update())
# - ✅ How to iterate through dictionaries effectively
# - ✅ The difference between dictionaries and lists
# - ✅ How to work with nested dictionaries
# - ✅ How to build real-world applications with dictionaries
#
# ### Key Takeaways:
# 💡 Dictionaries store data as key-value pairs
#
# 💡 Use meaningful keys to make your code self-documenting
#
# 💡 Use .get() to safely access keys that might not exist
#
# 💡 Use .items() to loop through both keys and values
#
# 💡 Dictionaries are perfect for labeled/structured data
#
# 💡 Keys must be unique, but values can be duplicated
#
# ### Next Steps:
# - Practice, practice, practice!
# - Try building your own dictionary-based applications
# - Experiment with nested dictionaries
# - Combine dictionaries with lists for more complex data structures
# - When ready, move on to Chapter 7 to learn about Functions!
#
# ### Pro Tips:
# 🔥 Dictionaries are one of the most used data structures in Python
#
# 🔥 Use dictionaries for configuration settings and JSON-like data
#
# 🔥 Dictionary lookups are very fast (O(1) time complexity)
#
# 🔥 Combine dictionaries with list comprehensions for powerful data processing
#
# 🔥 Use descriptive key names that make your code readable
#
# ---
#
# **Happy Coding! Keep building amazing things with dictionaries! 🚀**
