# %% [markdown]
# # Quiz 1 : Chapitres 1 & 2
#
# ## 📝 Testez vos connaissances !
#
# Ce quiz couvre tout ce qui concerne les chapitres 1 et 2 :
# - Variables et types de données
# - Opérations de base
# - Affichage de sortie
# - Entrée utilisateur
# - Conversion de types
# - Opérations sur les chaînes de caractères
#
# ### Instructions :
# 1. Lisez attentivement chaque question
# 2. Pour les choix multiples : Écrivez votre réponse dans la cellule désignée
# 3. Pour les problèmes de codage : Écrivez et testez votre code
# 4. Vérifiez vos réponses à la fin
#
# **Bonne chance ! 🍀**
#
# ---

# %% [markdown]
# ## Partie A : Questions à choix multiples
#
# Écrivez vos réponses (A, B, C ou D) dans les cellules sous chaque question.

# %% [markdown]
# ### Question 1
# Quelle est la bonne façon de créer une variable nommée `age` avec la valeur 25 ?
#
# A) `age = "25"`
#
# B) `age = 25`
#
# C) `25 = age`
#
# D) `age == 25`

# %%
# Your answer (A, B, C, or D):
answer_1 = ""

# %% [markdown]
# ### Question 2
# Quel est le type de données de la valeur `3.14` ?
#
# A) int
#
# B) str
#
# C) float
#
# D) bool

# %%
# Your answer:
answer_2 = ""

# %% [markdown]
# ### Question 3
# Qu'affichera `print("Hello" + "World")` ?
#
# A) Hello World
#
# B) HelloWorld
#
# C) Hello+World
#
# D) Erreur

# %%
# Your answer:
answer_3 = ""

# %% [markdown]
# ### Question 4
# Que retourne `10 % 3` ?
#
# A) 3
#
# B) 1
#
# C) 3.33
#
# D) 0

# %%
# Your answer:
answer_4 = ""

# %% [markdown]
# ### Question 5
# Que retourne la fonction `input()` ?
#
# A) Un entier
#
# B) Un nombre à virgule flottante
#
# C) Une chaîne de caractères
#
# D) Cela dépend de ce que l'utilisateur tape

# %%
# Your answer:
answer_5 = ""

# %% [markdown]
# ### Question 6
# Comment convertir la chaîne "42" en entier ?
#
# A) `float("42")`
#
# B) `int("42")`
#
# C) `str("42")`
#
# D) `"42".toInt()`

# %%
# Your answer:
answer_6 = ""

# %% [markdown]
# ### Question 7
# Que retournera `"hello".upper()` ?
#
# A) "hello"
#
# B) "HELLO"
#
# C) "Hello"
#
# D) Erreur

# %%
# Your answer:
answer_7 = ""

# %% [markdown]
# ### Question 8
# Quel est le résultat de `"Python" * 3` ?
#
# A) Erreur
#
# B) "Python3"
#
# C) "PythonPythonPython"
#
# D) 3

# %%
# Your answer:
answer_8 = ""

# %% [markdown]
# ### Question 9
# Quel symbole est utilisé pour les commentaires sur une seule ligne en Python ?
#
# A) //
#
# B) #
#
# C) /*
#
# D) --

# %%
# Your answer:
answer_9 = ""

# %% [markdown]
# ### Question 10
# Quel sera le résultat de `len("Python")` ?
#
# A) 5
#
# B) 6
#
# C) 7
#
# D) Erreur

# %%
# Your answer:
answer_10 = ""

# %% [markdown]
# ---
# ## Partie B : Vrai ou Faux
#
# Écrivez `True` ou `False` pour chaque affirmation.

# %% [markdown]
# ### Question 11
# Les noms de variables en Python peuvent commencer par un chiffre.

# %%
# Your answer (True or False):
answer_11 = None

# %% [markdown]
# ### Question 12
# L'expression `"5" + "3"` donne la chaîne `"53"`.

# %%
# Your answer:
answer_12 = None

# %% [markdown]
# ### Question 13
# Vous pouvez utiliser à la fois les guillemets simples (') et les guillemets doubles (") pour créer des chaînes en Python.

# %%
# Your answer:
answer_13 = None

# %% [markdown]
# ### Question 14
# L'opération `int(3.9)` retournera `4`.

# %%
# Your answer:
answer_14 = None

# %% [markdown]
# ### Question 15
# Les commentaires en Python sont exécutés par l'interpréteur.

# %%
# Your answer:
answer_15 = None

# %% [markdown]
# ---
# ## Partie C : Prédiction de sortie de code
#
# Qu'est-ce qui sera affiché ? Écrivez votre prédiction, puis exécutez le code pour vérifier.

# %% [markdown]
# ### Question 16
# ```python
# x = 10
# y = 3
# print(x // y)
# ```

# %%
# Your prediction:
prediction_16 = ""

# Run to check:
x = 10
y = 3
print(x // y)

# %% [markdown]
# ### Question 17
# ```python
# name = "python"
# print(name.title())
# ```

# %%
# Your prediction:
prediction_17 = ""

# Run to check:
name = "python"
print(name.title())

# %% [markdown]
# ### Question 18
# ```python
# a = "5"
# b = int(a)
# result = b + 10
# print(result)
# ```

# %%
# Your prediction:
prediction_18 = ""

# Run to check:
a = "5"
b = int(a)
result = b + 10
print(result)

# %% [markdown]
# ### Question 19
# ```python
# text = "  Hello  "
# print(text.strip())
# ```

# %%
# Your prediction:
prediction_19 = ""

# Run to check:
text = "  Hello  "
print(text.strip())

# %% [markdown]
# ### Question 20
# ```python
# num = 7
# num += 3
# num *= 2
# print(num)
# ```

# %%
# Your prediction:
prediction_20 = ""

# Run to check:
num = 7
num += 3
num *= 2
print(num)

# %% [markdown]
# ---
# ## Partie D : Défis de codage
#
# Écrivez du code pour résoudre ces problèmes.

# %% [markdown]
# ### Défi 1 : Création de variables
# Créez trois variables :
# - `product_name` avec la valeur "Laptop"
# - `price` avec la valeur 999.99
# - `quantity` avec la valeur 3
#
# Puis affichez les trois dans un message formaté.

# %%
# Write your code here

# %% [markdown]
# ### Défi 2 : Opérations mathématiques
# Calculez et affichez :
# - La somme de 156 et 244
# - Le produit de 12 et 13
# - 2 à la puissance 8
# - Le reste de la division de 50 par 7

# %%
# Write your code here

# %% [markdown]
# ### Défi 3 : Manipulation de chaînes
# Étant donné la variable `city = "casablanca"`, utilisez les méthodes de chaîne pour :
# 1. L'afficher en majuscules
# 2. L'afficher avec la première lettre en majuscule
# 3. Afficher la longueur de la chaîne

# %%
# Write your code here
city = "casablanca"

# %% [markdown]
# ### Défi 4 : Conversion de types
# Étant donné :
# ```python
# text_num = "42"
# ```
# Convertissez-le en entier, multipliez par 2, puis affichez le résultat.

# %%
# Write your code here
text_num = "42"

# %% [markdown]
# ### Défi 5 : Calculateur d'âge interactif
# Écrivez un programme qui :
# 1. Demande à l'utilisateur son âge
# 2. Le convertit en entier
# 3. Calcule son âge dans 10 ans
# 4. Affiche le résultat

# %%
# Write your code here

# %% [markdown]
# ### Défi 6 : Calculateur de prix
# Écrivez un programme qui :
# 1. Demande le prix d'un article (float)
# 2. Demande la quantité (int)
# 3. Calcule le coût total
# 4. Applique une réduction de 10%
# 5. Affiche le prix final

# %%
# Write your code here

# %% [markdown]
# ### Défi 7 : Formateur de nom
# Écrivez un programme qui :
# 1. Demande le prénom
# 2. Demande le nom de famille
# 3. Les combine en un nom complet
# 4. Affiche le nom complet en majuscules
# 5. Affiche le nom complet en casse de titre
# 6. Affiche la longueur du nom complet

# %%
# Write your code here

# %% [markdown]
# ### Défi 8 : Convertisseur de température
# Créez un convertisseur Celsius vers Fahrenheit :
# - Demandez à l'utilisateur la température en Celsius
# - Convertissez en Fahrenheit en utilisant : F = (C × 9/5) + 32
# - Affichez les deux températures

# %%
# Write your code here

# %% [markdown]
# ### Défi 9 : Propriétés d'un cercle
# Écrivez un programme qui :
# 1. Demande à l'utilisateur le rayon du cercle
# 2. Calcule la circonférence : 2 × π × rayon (utilisez π = 3.14159)
# 3. Calcule l'aire : π × rayon²
# 4. Affiche les deux résultats avec des étiquettes

# %%
# Write your code here

# %% [markdown]
# ### Défi 10 : Créer une carte de visite
# Écrivez un programme qui demande :
# - Nom
# - Titre du poste
# - Entreprise
# - Email
#
# Puis les affiche dans une "carte de visite" joliment formatée en utilisant des instructions print.

# %%
# Write your code here
# Use print with decorative characters (*, =, -, etc.) to make it look nice

# %% [markdown]
# ---
# ## Partie E : Défi de débogage
#
# Chaque extrait de code ci-dessous contient une erreur. Identifiez-la et corrigez-la.

# %% [markdown]
# ### Débogage 1
# ```python
# age = input("Enter age: ")
# next_year = age + 1
# print(next_year)
# ```

# %%
# Fix the code:

# %% [markdown]
# ### Débogage 2
# ```python
# name = "Python
# print(name)
# ```

# %%
# Fix the code:

# %% [markdown]
# ### Débogage 3
# ```python
# result = "5" + 5
# print(result)
# ```

# %%
# Fix the code (two possible solutions):

# %% [markdown]
# ### Débogage 4
# ```python
# price = 99.99
# message = "The price is " + price
# print(message)
# ```

# %%
# Fix the code:

# %% [markdown]
# ### Débogage 5
# ```python
# number = int("hello")
# print(number)
# ```

# %%
# Fix the code:

# %% [markdown]
# ---
# ## Corrigé
#
# ### Partie A : Choix multiples
# 1. B
# 2. C
# 3. B
# 4. B
# 5. C
# 6. B
# 7. B
# 8. C
# 9. B
# 10. B
#
# ### Partie B : Vrai ou Faux
# 11. False (Les noms de variables ne peuvent pas commencer par un chiffre)
# 12. True
# 13. True
# 14. False (int() tronque, n'arrondit pas. Retourne 3)
# 15. False (Les commentaires sont ignorés par Python)
#
# ### Partie C : Prédictions
# 16. 3
# 17. Python
# 18. 15
# 19. Hello
# 20. 20
#
# ---
# ## Guide de notation
#
# **Choix multiples (10 points)** : 1 point chacun
#
# **Vrai/Faux (5 points)** : 1 point chacun
#
# **Prédictions (5 points)** : 1 point chacun
#
# **Défis de codage (10 points)** : 1 point chacun
#
# **Débogage (5 points)** : 1 point chacun
#
# **Total : 35 points**
#
# ### Échelle de notation :
# - 32-35 : Excellent ! 🌟
# - 28-31 : Très bien ! 👏
# - 24-27 : Bon travail ! 👍
# - 20-23 : Continuez à pratiquer ! 📚
# - En dessous de 20 : Révisez les chapitres et réessayez ! 💪
#
# ---
#
# ## 🎉 Quiz terminé !
#
# Comment avez-vous réussi ?
#
# - Si vous avez bien réussi : Excellent travail ! Passez au chapitre 3 !
# - Si vous avez eu des difficultés : Révisez les chapitres concernés et pratiquez davantage
# - Dans tous les cas : La pratique est la clé pour maîtriser la programmation !
#
# **Continuez à coder ! 🚀**
