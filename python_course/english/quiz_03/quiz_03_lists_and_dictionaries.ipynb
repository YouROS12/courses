# %% [markdown]
# # Quiz 3: Chapter 5 - Lists
#
# ## 📝 Test Your Knowledge!
#
# This quiz covers everything from Chapter 5:
# - Creating lists
# - Accessing elements (indexing)
# - Slicing lists
# - List methods (append, insert, remove, pop, sort, reverse, etc.)
# - Iterating through lists
# - List operations (concatenation, repetition)
# - Common list functions (len, min, max, sum)
# - Checking membership (in operator)
#
# ### Instructions:
# 1. Read each question carefully
# 2. For multiple choice: Write your answer in the designated cell
# 3. For coding problems: Write and test your code
# 4. Check your answers at the end
#
# **Good luck! 🍀**
#
# ---

# %% [markdown]
# ## Part A: Multiple Choice Questions
#
# Write your answers (A, B, C, or D) in the cells below each question.

# %% [markdown]
# ### Question 1
# What is the correct way to create an empty list?
#
# A) `my_list = ()`
#
# B) `my_list = []`
#
# C) `my_list = {}`
#
# D) `my_list = list`

# %%
# Your answer (A, B, C, or D):
answer_1 = ""

# %% [markdown]
# ### Question 2
# What will `fruits[1]` return if `fruits = ["apple", "banana", "cherry"]`?
#
# A) apple
#
# B) banana
#
# C) cherry
#
# D) Error

# %%
# Your answer:
answer_2 = ""

# %% [markdown]
# ### Question 3
# What does the `append()` method do?
#
# A) Removes the last element from a list
#
# B) Adds an element to the beginning of a list
#
# C) Adds an element to the end of a list
#
# D) Sorts the list

# %%
# Your answer:
answer_3 = ""

# %% [markdown]
# ### Question 4
# What does `numbers[-1]` access in a list?
#
# A) The first element
#
# B) The last element
#
# C) The second element
#
# D) It causes an error

# %%
# Your answer:
answer_4 = ""

# %% [markdown]
# ### Question 5
# What will `[1, 2] + [3, 4]` produce?
#
# A) [1, 2, 3, 4]
#
# B) [4, 6]
#
# C) [[1, 2], [3, 4]]
#
# D) Error

# %%
# Your answer:
answer_5 = ""

# %% [markdown]
# ### Question 6
# Which method removes and returns the last element from a list?
#
# A) `remove()`
#
# B) `delete()`
#
# C) `pop()`
#
# D) `drop()`

# %%
# Your answer:
answer_6 = ""

# %% [markdown]
# ---
# ## Part B: True or False
#
# Write `True` or `False` for each statement.

# %% [markdown]
# ### Question 7
# Lists in Python can contain elements of different data types (integers, strings, floats, etc.).

# %%
# Your answer (True or False):
answer_7 = None

# %% [markdown]
# ### Question 8
# List indexing in Python starts at 1.

# %%
# Your answer:
answer_8 = None

# %% [markdown]
# ### Question 9
# The `sort()` method sorts a list in place and returns None.

# %%
# Your answer:
answer_9 = None

# %% [markdown]
# ### Question 10
# You can use the `in` operator to check if an element exists in a list.

# %%
# Your answer:
answer_10 = None

# %% [markdown]
# ---
# ## Part C: Code Output Prediction
#
# What will be printed? Write your prediction, then run the code to check.

# %% [markdown]
# ### Question 11
# ```python
# numbers = [10, 20, 30, 40, 50]
# print(numbers[2:4])
# ```

# %%
# Your prediction:
prediction_11 = ""

# Run to check:
numbers = [10, 20, 30, 40, 50]
print(numbers[2:4])

# %% [markdown]
# ### Question 12
# ```python
# fruits = ["apple", "banana"]
# fruits.append("cherry")
# print(len(fruits))
# ```

# %%
# Your prediction:
prediction_12 = ""

# Run to check:
fruits = ["apple", "banana"]
fruits.append("cherry")
print(len(fruits))

# %% [markdown]
# ### Question 13
# ```python
# numbers = [3, 1, 4, 1, 5]
# numbers.sort()
# print(numbers)
# ```

# %%
# Your prediction:
prediction_13 = ""

# Run to check:
numbers = [3, 1, 4, 1, 5]
numbers.sort()
print(numbers)

# %% [markdown]
# ### Question 14
# ```python
# my_list = [1, 2, 3]
# print(my_list * 2)
# ```

# %%
# Your prediction:
prediction_14 = ""

# Run to check:
my_list = [1, 2, 3]
print(my_list * 2)

# %% [markdown]
# ---
# ## Part D: Coding Challenges
#
# Write code to solve these problems.

# %% [markdown]
# ### Challenge 1: Shopping List Manager
# Create a shopping list program that:
# 1. Creates an empty list called `shopping_list`
# 2. Adds 5 items to the list using `append()`
# 3. Prints the entire list
# 4. Prints the first item
# 5. Prints the last item
# 6. Prints the number of items in the list

# %%
# Write your code here

# %% [markdown]
# ### Challenge 2: List Statistics
# Given a list of test scores, write a program that:
# 1. Creates a list: `scores = [85, 92, 78, 90, 88]`
# 2. Prints the highest score using `max()`
# 3. Prints the lowest score using `min()`
# 4. Prints the total of all scores using `sum()`
# 5. Calculates and prints the average score
# 6. Checks if score 90 is in the list and prints the result

# %%
# Write your code here

# %% [markdown]
# ---
# ## Part E: Debugging Challenge
#
# Each code snippet below has an error. Identify and fix it.

# %% [markdown]
# ### Debug 1
# ```python
# colors = ["red", "green", "blue"]
# print(colors[3])
# ```

# %%
# Fix the code:

# %% [markdown]
# ### Debug 2
# ```python
# numbers = [5, 2, 8, 1, 9]
# result = numbers.sort()
# print(result)
# ```

# %%
# Fix the code:

# %% [markdown]
# ---
# ## Answer Key

# %% [markdown]
# ### Part A: Multiple Choice
# 1. B - `my_list = []` is the correct way to create an empty list
# 2. B - Lists use zero-based indexing, so index 1 is the second element (banana)
# 3. C - `append()` adds an element to the end of a list
# 4. B - Negative indexing accesses elements from the end, -1 is the last element
# 5. A - The + operator concatenates lists: [1, 2, 3, 4]
# 6. C - `pop()` removes and returns the last element
#
# ### Part B: True or False
# 7. True - Lists can contain mixed data types
# 8. False - Python lists use zero-based indexing (start at 0)
# 9. True - `sort()` modifies the list in place and returns None
# 10. True - The `in` operator checks for membership in a list
#
# ### Part C: Code Output Predictions
# 11. [30, 40] - Slicing from index 2 to 4 (exclusive) gives elements at indices 2 and 3
# 12. 3 - After appending cherry, the list has 3 elements
# 13. [1, 1, 3, 4, 5] - The list is sorted in ascending order
# 14. [1, 2, 3, 1, 2, 3] - List repetition repeats all elements
#
# ---
# ## Scoring Guide
#
# **Multiple Choice (6 points)**: 1 point each
#
# **True/False (4 points)**: 1 point each
#
# **Code Predictions (4 points)**: 1 point each
#
# **Coding Challenges (2 points)**: 1 point each
#
# **Debugging (2 points)**: 1 point each
#
# **Total: 18 points**
#
# ### Grade Scale:
# - 17-18: Excellent! 🌟
# - 15-16: Great job! 👏
# - 13-14: Good work! 👍
# - 11-12: Keep practicing! 📚
# - Below 11: Review Chapter 5 and try again! 💪
#
# ---
#
# ## 🎉 Quiz Complete!
#
# How did you do?
#
# - If you scored well: Fantastic! You understand lists in Python!
# - If you struggled: Review Chapter 5, focusing on:
#   - List indexing (remember it starts at 0!)
#   - The difference between methods that modify lists in place (like `sort()`, `append()`) vs. those that return new values
#   - List slicing syntax
#   - Common list functions and methods
#
# **Lists are fundamental to Python - keep practicing! 🚀**
#
# ### Sample Solutions for Challenges:

# %% [markdown]
# ### Challenge 1: Shopping List Manager - Sample Solution
# ```python
# # Create empty shopping list
# shopping_list = []
#
# # Add 5 items
# shopping_list.append("milk")
# shopping_list.append("bread")
# shopping_list.append("eggs")
# shopping_list.append("butter")
# shopping_list.append("cheese")
#
# # Print entire list
# print("Shopping list:", shopping_list)
#
# # Print first item
# print("First item:", shopping_list[0])
#
# # Print last item
# print("Last item:", shopping_list[-1])
#
# # Print number of items
# print("Number of items:", len(shopping_list))
# ```

# %% [markdown]
# ### Challenge 2: List Statistics - Sample Solution
# ```python
# # Create list of scores
# scores = [85, 92, 78, 90, 88]
#
# # Print highest score
# print("Highest score:", max(scores))
#
# # Print lowest score
# print("Lowest score:", min(scores))
#
# # Print total of all scores
# print("Total:", sum(scores))
#
# # Calculate and print average
# average = sum(scores) / len(scores)
# print("Average:", average)
#
# # Check if 90 is in the list
# print("Is 90 in the list?", 90 in scores)
# ```

# %% [markdown]
# ### Debugging Solutions

# %% [markdown]
# **Debug 1:** Index out of range - the list has only 3 elements (indices 0, 1, 2)
# ```python
# colors = ["red", "green", "blue"]
# print(colors[2])  # Changed from colors[3] to colors[2]
# # Or use colors[-1] to get the last element
# ```

# %% [markdown]
# **Debug 2:** The `sort()` method returns None, not the sorted list
# ```python
# numbers = [5, 2, 8, 1, 9]
# numbers.sort()  # Don't assign the result
# print(numbers)  # Print the list itself
#
# # Alternative: Use sorted() function which returns a new sorted list
# # numbers = [5, 2, 8, 1, 9]
# # result = sorted(numbers)
# # print(result)
# ```
