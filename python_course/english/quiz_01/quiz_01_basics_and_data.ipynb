# %% [markdown]
# # Quiz 1: Chapters 1 & 2
#
# ## 📝 Test Your Knowledge!
#
# This quiz covers everything from Chapters 1 and 2:
# - Variables and data types
# - Basic operations
# - Printing output
# - User input
# - Type conversion
# - String operations
#
# ### Instructions:
# 1. Read each question carefully
# 2. For multiple choice: Write your answer in the designated cell
# 3. For coding problems: Write and test your code
# 4. Check your answers at the end
#
# **Good luck! 🍀**
#
# ---

# %% [markdown]
# ## Part A: Multiple Choice Questions
#
# Write your answers (A, B, C, or D) in the cells below each question.

# %% [markdown]
# ### Question 1
# What is the correct way to create a variable named `age` with value 25?
#
# A) `age = "25"`
#
# B) `age = 25`
#
# C) `25 = age`
#
# D) `age == 25`

# %%
# Your answer (A, B, C, or D):
answer_1 = ""

# %% [markdown]
# ### Question 2
# What data type is the value `3.14`?
#
# A) int
#
# B) str
#
# C) float
#
# D) bool

# %%
# Your answer:
answer_2 = ""

# %% [markdown]
# ### Question 3
# What will `print("Hello" + "World")` display?
#
# A) Hello World
#
# B) HelloWorld
#
# C) Hello+World
#
# D) Error

# %%
# Your answer:
answer_3 = ""

# %% [markdown]
# ### Question 4
# What does `10 % 3` return?
#
# A) 3
#
# B) 1
#
# C) 3.33
#
# D) 0

# %%
# Your answer:
answer_4 = ""

# %% [markdown]
# ### Question 5
# What does the `input()` function return?
#
# A) An integer
#
# B) A float
#
# C) A string
#
# D) It depends on what the user types

# %%
# Your answer:
answer_5 = ""

# %% [markdown]
# ### Question 6
# How do you convert the string "42" to an integer?
#
# A) `float("42")`
#
# B) `int("42")`
#
# C) `str("42")`
#
# D) `"42".toInt()`

# %%
# Your answer:
answer_6 = ""

# %% [markdown]
# ### Question 7
# What will `"hello".upper()` return?
#
# A) "hello"
#
# B) "HELLO"
#
# C) "Hello"
#
# D) Error

# %%
# Your answer:
answer_7 = ""

# %% [markdown]
# ### Question 8
# What is the result of `"Python" * 3`?
#
# A) Error
#
# B) "Python3"
#
# C) "PythonPythonPython"
#
# D) 3

# %%
# Your answer:
answer_8 = ""

# %% [markdown]
# ### Question 9
# Which symbol is used for single-line comments in Python?
#
# A) //
#
# B) #
#
# C) /*
#
# D) --

# %%
# Your answer:
answer_9 = ""

# %% [markdown]
# ### Question 10
# What will be the result of `len("Python")`?
#
# A) 5
#
# B) 6
#
# C) 7
#
# D) Error

# %%
# Your answer:
answer_10 = ""

# %% [markdown]
# ---
# ## Part B: True or False
#
# Write `True` or `False` for each statement.

# %% [markdown]
# ### Question 11
# Variable names in Python can start with a number.

# %%
# Your answer (True or False):
answer_11 = None

# %% [markdown]
# ### Question 12
# The expression `"5" + "3"` results in the string `"53"`.

# %%
# Your answer:
answer_12 = None

# %% [markdown]
# ### Question 13
# You can use both single quotes (') and double quotes (") to create strings in Python.

# %%
# Your answer:
answer_13 = None

# %% [markdown]
# ### Question 14
# The operation `int(3.9)` will return `4`.

# %%
# Your answer:
answer_14 = None

# %% [markdown]
# ### Question 15
# Comments in Python are executed by the interpreter.

# %%
# Your answer:
answer_15 = None

# %% [markdown]
# ---
# ## Part C: Code Output Prediction
#
# What will be printed? Write your prediction, then run the code to check.

# %% [markdown]
# ### Question 16
# ```python
# x = 10
# y = 3
# print(x // y)
# ```

# %%
# Your prediction:
prediction_16 = ""

# Run to check:
x = 10
y = 3
print(x // y)

# %% [markdown]
# ### Question 17
# ```python
# name = "python"
# print(name.title())
# ```

# %%
# Your prediction:
prediction_17 = ""

# Run to check:
name = "python"
print(name.title())

# %% [markdown]
# ### Question 18
# ```python
# a = "5"
# b = int(a)
# result = b + 10
# print(result)
# ```

# %%
# Your prediction:
prediction_18 = ""

# Run to check:
a = "5"
b = int(a)
result = b + 10
print(result)

# %% [markdown]
# ### Question 19
# ```python
# text = "  Hello  "
# print(text.strip())
# ```

# %%
# Your prediction:
prediction_19 = ""

# Run to check:
text = "  Hello  "
print(text.strip())

# %% [markdown]
# ### Question 20
# ```python
# num = 7
# num += 3
# num *= 2
# print(num)
# ```

# %%
# Your prediction:
prediction_20 = ""

# Run to check:
num = 7
num += 3
num *= 2
print(num)

# %% [markdown]
# ---
# ## Part D: Coding Challenges
#
# Write code to solve these problems.

# %% [markdown]
# ### Challenge 1: Variable Creation
# Create three variables:
# - `product_name` with the value "Laptop"
# - `price` with the value 999.99
# - `quantity` with the value 3
#
# Then print all three in a formatted message.

# %%
# Write your code here

# %% [markdown]
# ### Challenge 2: Math Operations
# Calculate and print:
# - The sum of 156 and 244
# - The product of 12 and 13
# - 2 to the power of 8
# - The remainder when 50 is divided by 7

# %%
# Write your code here

# %% [markdown]
# ### Challenge 3: String Manipulation
# Given the variable `city = "casablanca"`, use string methods to:
# 1. Print it in uppercase
# 2. Print it with the first letter capitalized
# 3. Print the length of the string

# %%
# Write your code here
city = "casablanca"

# %% [markdown]
# ### Challenge 4: Type Conversion
# Given:
# ```python
# text_num = "42"
# ```
# Convert it to an integer, multiply by 2, then print the result.

# %%
# Write your code here
text_num = "42"

# %% [markdown]
# ### Challenge 5: Interactive Age Calculator
# Write a program that:
# 1. Asks the user for their age
# 2. Converts it to an integer
# 3. Calculates how old they'll be in 10 years
# 4. Prints the result

# %%
# Write your code here

# %% [markdown]
# ### Challenge 6: Price Calculator
# Write a program that:
# 1. Asks for an item price (float)
# 2. Asks for quantity (int)
# 3. Calculates total cost
# 4. Applies a 10% discount
# 5. Prints the final price

# %%
# Write your code here

# %% [markdown]
# ### Challenge 7: Name Formatter
# Write a program that:
# 1. Asks for first name
# 2. Asks for last name
# 3. Combines them into a full name
# 4. Prints the full name in uppercase
# 5. Prints the full name in title case
# 6. Prints the length of the full name

# %%
# Write your code here

# %% [markdown]
# ### Challenge 8: Temperature Converter
# Create a Celsius to Fahrenheit converter:
# - Ask user for temperature in Celsius
# - Convert to Fahrenheit using: F = (C × 9/5) + 32
# - Display both temperatures

# %%
# Write your code here

# %% [markdown]
# ### Challenge 9: Circle Properties
# Write a program that:
# 1. Asks user for circle radius
# 2. Calculates circumference: 2 × π × radius (use π = 3.14159)
# 3. Calculates area: π × radius²
# 4. Displays both results with labels

# %%
# Write your code here

# %% [markdown]
# ### Challenge 10: Create a Business Card
# Write a program that asks for:
# - Name
# - Job title
# - Company
# - Email
#
# Then displays them in a nicely formatted "business card" using print statements.

# %%
# Write your code here
# Use print with decorative characters (*, =, -, etc.) to make it look nice

# %% [markdown]
# ---
# ## Part E: Debugging Challenge
#
# Each code snippet below has an error. Identify and fix it.

# %% [markdown]
# ### Debug 1
# ```python
# age = input("Enter age: ")
# next_year = age + 1
# print(next_year)
# ```

# %%
# Fix the code:

# %% [markdown]
# ### Debug 2
# ```python
# name = "Python
# print(name)
# ```

# %%
# Fix the code:

# %% [markdown]
# ### Debug 3
# ```python
# result = "5" + 5
# print(result)
# ```

# %%
# Fix the code (two possible solutions):

# %% [markdown]
# ### Debug 4
# ```python
# price = 99.99
# message = "The price is " + price
# print(message)
# ```

# %%
# Fix the code:

# %% [markdown]
# ### Debug 5
# ```python
# number = int("hello")
# print(number)
# ```

# %%
# Fix the code:

# %% [markdown]
# ---
# ## Answer Key
#
# ### Part A: Multiple Choice
# 1. B
# 2. C
# 3. B
# 4. B
# 5. C
# 6. B
# 7. B
# 8. C
# 9. B
# 10. B
#
# ### Part B: True or False
# 11. False (Variable names cannot start with a number)
# 12. True
# 13. True
# 14. False (int() truncates, doesn't round. Returns 3)
# 15. False (Comments are ignored by Python)
#
# ### Part C: Predictions
# 16. 3
# 17. Python
# 18. 15
# 19. Hello
# 20. 20
#
# ---
# ## Scoring Guide
#
# **Multiple Choice (10 points)**: 1 point each
#
# **True/False (5 points)**: 1 point each
#
# **Predictions (5 points)**: 1 point each
#
# **Coding Challenges (10 points)**: 1 point each
#
# **Debugging (5 points)**: 1 point each
#
# **Total: 35 points**
#
# ### Grade Scale:
# - 32-35: Excellent! 🌟
# - 28-31: Great job! 👏
# - 24-27: Good work! 👍
# - 20-23: Keep practicing! 📚
# - Below 20: Review the chapters and try again! 💪
#
# ---
#
# ## 🎉 Quiz Complete!
#
# How did you do?
#
# - If you scored well: Great job! Move on to Chapter 3!
# - If you struggled: Review the relevant chapters and practice more
# - Either way: Practice is key to mastering programming!
#
# **Keep coding! 🚀**
