# %% [markdown]
# # Chapter 2: Working with Data - Practice Notebook
#
# Welcome to Chapter 2! In this session, you'll learn how to create **interactive programs** that talk to users. 🎙️
#
# By the end, you'll be able to:
# - Get input from users
# - Convert between different data types
# - Manipulate strings like a pro
# - Write clean code with comments
# - Understand and fix common errors
#
# ---

# %% [markdown]
# ## Part 1: Getting User Input 💬
#
# The `input()` function makes your programs interactive!

# %%
# Basic input - ask for user's name
name = input("What is your name? ")
print("Hello,", name)

# %%
# Multiple inputs
name = input("Enter your name: ")
city = input("Enter your city: ")

print(f"Hello {name} from {city}!")

# %%
# IMPORTANT: input() always returns a string
value = input("Enter a number: ")

print("You entered:", value)
print("Type:", type(value))  # This will show <class 'str'>

# %% [markdown]
# ### ✏️ Exercise 1.1: Favorite Things
# Ask the user for their favorite color, food, and hobby. Then display all three.

# %%
# Write your code here

# %% [markdown]
# ---
# ## Part 2: The Problem with Input 🤔
#
# When you use `input()`, everything comes back as text (a string), even if you type numbers!

# %%
# This will cause an error!
# Try running it to see what happens

age = input("How old are you? ")

# Trying to add 1 to a string won't work
# Uncomment the line below to see the error:
# next_year = age + 1  # This will give TypeError

# %%
# Let's see why this happens
age = input("Enter your age: ")

print("You entered:", age)
print("Type:", type(age))  # It's a string!
print("Is it a string?", type(age) == str)  # True

# %% [markdown]
# ---
# ## Part 3: Type Conversion - The Solution! 🔄
#
# We can convert strings to numbers (and vice versa) using type conversion functions.

# %% [markdown]
# ### Converting to Integer - int()

# %%
# String to integer
text_number = "42"
real_number = int(text_number)

print("Original:", text_number, "Type:", type(text_number))
print("Converted:", real_number, "Type:", type(real_number))

# %%
# Now we can do math!
text_num = "25"
number = int(text_num)

result = number + 10
print(f"{number} + 10 = {result}")

# %%
# Float to int (removes decimal part)
decimal = 3.9
whole = int(decimal)

print(f"{decimal} becomes {whole}")  # 3.9 becomes 3

# %% [markdown]
# ### Converting to Float - float()

# %%
# String to float
text_price = "19.99"
price = float(text_price)

print("Original:", text_price, "Type:", type(text_price))
print("Converted:", price, "Type:", type(price))

# %%
# Integer to float
whole_number = 5
decimal_number = float(whole_number)

print(f"{whole_number} becomes {decimal_number}")  # 5 becomes 5.0

# %% [markdown]
# ### Converting to String - str()

# %%
# Number to string
age = 25
age_text = str(age)

print("Original:", age, "Type:", type(age))
print("Converted:", age_text, "Type:", type(age_text))

# %%
# Why convert to string? For concatenation!
score = 100
message = "Your score is " + str(score) + " points!"
print(message)

# %% [markdown]
# ### ✏️ Exercise 3.1: Type Conversion Practice
# 1. Convert "123" to an integer and add 77 to it
# 2. Convert 9.99 to a string and add " dollars" to it
# 3. Convert "3.14159" to a float and multiply by 2

# %%
# Write your code here

# %% [markdown]
# ---
# ## Part 4: Input with Type Conversion 🚀
#
# You can combine `input()` with type conversion in one line!

# %%
# Get an integer from user (combined)
age = int(input("Enter your age: "))

# Now age is already an integer, ready for math!
next_year = age + 1
print(f"Next year you'll be {next_year} years old")

# %%
# Get a float from user
price = float(input("Enter the price: $"))
quantity = int(input("Enter quantity: "))

total = price * quantity
print(f"Total cost: ${total}")

# %%
# Building a simple calculator
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print(f"Sum: {num1 + num2}")
print(f"Difference: {num1 - num2}")
print(f"Product: {num1 * num2}")
print(f"Division: {num1 / num2}")

# %% [markdown]
# ### ✏️ Exercise 4.1: Rectangle Calculator
# Ask the user for length and width of a rectangle. Calculate and display the area and perimeter.

# %%
# Write your code here
# Area = length × width
# Perimeter = 2 × (length + width)

# %% [markdown]
# ---
# ## Part 5: String Operations ✂️
#
# Strings have many useful methods and operations!

# %% [markdown]
# ### String Concatenation (Joining)

# %%
# Using + operator
first_name = "Ahmed"
last_name = "Hassan"

full_name = first_name + " " + last_name
print(full_name)

# %%
# Building sentences
greeting = "Hello"
name = "Sarah"
punctuation = "!"

message = greeting + " " + name + punctuation
print(message)  # Hello Sarah!

# %% [markdown]
# ### String Repetition

# %%
# Repeat strings with *
print("Ha" * 5)  # HaHaHaHaHa
print("=" * 20)  # ====================
print("Python! " * 3)  # Python! Python! Python!

# %%
# Create visual separators
print("*" * 30)
print("      WELCOME TO PYTHON")
print("*" * 30)

# %% [markdown]
# ### String Methods

# %%
# upper() - Convert to uppercase
text = "hello world"
print(text.upper())  # HELLO WORLD

# %%
# lower() - Convert to lowercase
text = "HELLO WORLD"
print(text.lower())  # hello world

# %%
# title() - Capitalize first letter of each word
text = "python programming is fun"
print(text.title())  # Python Programming Is Fun

# %%
# capitalize() - Capitalize only first letter
text = "python programming"
print(text.capitalize())  # Python programming

# %%
# strip() - Remove leading/trailing spaces
text = "   hello   "
print(f"'{text}'")  # '   hello   '
print(f"'{text.strip()}'")  # 'hello'

# %%
# replace() - Replace parts of a string
text = "I love cats"
new_text = text.replace("cats", "dogs")
print(new_text)  # I love dogs

# %%
# count() - Count occurrences
text = "hello hello hello"
count = text.count("hello")
print(f"'hello' appears {count} times")

# %%
# len() - Get string length
text = "Python"
length = len(text)
print(f"'{text}' has {length} characters")

# %% [markdown]
# ### ✏️ Exercise 5.1: String Manipulation
# Ask the user for their name, then:
# 1. Display it in uppercase
# 2. Display it in lowercase
# 3. Display the length
# 4. Create a greeting that repeats their name 3 times

# %%
# Write your code here

# %% [markdown]
# ---
# ## Part 6: Comments - Documenting Your Code 📝
#
# Comments help you and others understand your code!

# %%
# This is a single-line comment
# Python completely ignores it

price = 100  # You can also put comments at the end of lines
print(price)

# %%
"""
This is a multi-line comment (docstring)
It can span multiple lines
Useful for longer explanations
"""

def calculate_total():
    total = 100 + 200
    return total

print(calculate_total())

# %%
# Good comment: Explains WHY
# Calculate discount for orders over $100 to encourage larger purchases
order_total = 150
if order_total > 100:
    discount = order_total * 0.1

# %%
# Comments can temporarily disable code
price = 50
# price = 60  # This line won't execute
print(price)  # Prints 50

# %% [markdown]
# ---
# ## Part 7: Understanding Errors 🐛
#
# Errors are your friends - they tell you what's wrong!

# %% [markdown]
# ### ValueError - Invalid Conversion

# %%
# This will cause a ValueError
# Uncomment to see the error:
# number = int("hello")  # Can't convert "hello" to integer!

# %%
# This works fine
number = int("123")  # "123" can be converted to 123
print(number)

# %% [markdown]
# ### TypeError - Incompatible Types

# %%
# This will cause a TypeError
# Uncomment to see the error:
# result = "5" + 5  # Can't add string and integer!

# %%
# Fix it by converting
result1 = int("5") + 5  # Convert string to int
print(result1)  # 10

result2 = "5" + str(5)  # Convert int to string
print(result2)  # "55"

# %% [markdown]
# ### SyntaxError - Invalid Python Code

# %%
# This will cause a SyntaxError
# Uncomment to see the error:
# print("Hello"  # Missing closing parenthesis

# %%
# Fixed version
print("Hello")  # All parentheses match!

# %% [markdown]
# ---
# ## Part 8: Real-World Applications 🌍
#
# Let's build interactive programs!

# %% [markdown]
# ### Example 1: Personalized Greeting

# %%
# Get user information
first_name = input("Enter your first name: ")
last_name = input("Enter your last name: ")

# Format nicely
full_name = (first_name + " " + last_name).title()

# Create personalized greeting
print("\n" + "=" * 40)
print(f"  Welcome, {full_name}!")
print("=" * 40)

# %% [markdown]
# ### Example 2: Age in Different Units

# %%
# Get age from user
age_years = int(input("How old are you? "))

# Convert to different units
age_months = age_years * 12
age_days = age_years * 365  # Approximate
age_hours = age_days * 24

# Display results
print(f"\nYou are:")
print(f"  {age_years} years old")
print(f"  {age_months} months old")
print(f"  {age_days} days old")
print(f"  {age_hours:,} hours old!")  # :, adds comma formatting

# %% [markdown]
# ### Example 3: Temperature Converter

# %%
# Celsius to Fahrenheit converter
celsius = float(input("Enter temperature in Celsius: "))

# Convert: F = (C × 9/5) + 32
fahrenheit = (celsius * 9/5) + 32

# Display result
print(f"\n{celsius}°C = {fahrenheit}°F")

# %% [markdown]
# ### Example 4: Restaurant Bill Splitter

# %%
# Get bill information
total_bill = float(input("Enter total bill amount: $"))
num_people = int(input("How many people? "))
tip_percent = float(input("Tip percentage (e.g., 15): "))

# Calculate
tip_amount = total_bill * (tip_percent / 100)
total_with_tip = total_bill + tip_amount
per_person = total_with_tip / num_people

# Display results
print("\n" + "=" * 40)
print(f"Original Bill: ${total_bill:.2f}")
print(f"Tip ({tip_percent}%): ${tip_amount:.2f}")
print(f"Total: ${total_with_tip:.2f}")
print(f"Per Person: ${per_person:.2f}")
print("=" * 40)

# %% [markdown]
# ### Example 5: Name Tag Generator

# %%
# Get user info
name = input("Enter your name: ")
title = input("Enter your title/role: ")
company = input("Enter company name: ")

# Format nicely
name_upper = name.upper()
title_title = title.title()
company_caps = company.upper()

# Create name tag
print("\n" + "*" * 50)
print("*" + " " * 48 + "*")
print(f"*  HELLO, MY NAME IS:")
print(f"*  {name_upper}")
print("*")
print(f"*  {title_title}")
print(f"*  {company_caps}")
print("*" + " " * 48 + "*")
print("*" * 50)

# %% [markdown]
# ---
# ## 🎯 Challenge Exercises
#
# Put your skills to the test!

# %% [markdown]
# ### Challenge 1: Username Generator
# Create a username from first name and birth year.
# Example: "Sarah" + "2000" → "sarah2000"

# %%
# Write your code here
# Ask for first name and birth year
# Convert name to lowercase
# Combine to create username

# %% [markdown]
# ### Challenge 2: Distance Converter
# Convert kilometers to miles (1 km = 0.621371 miles)

# %%
# Write your code here

# %% [markdown]
# ### Challenge 3: Seconds Converter
# Ask for a number of seconds, then convert to hours, minutes, and remaining seconds.
# Example: 3665 seconds = 1 hour, 1 minute, 5 seconds

# %%
# Write your code here
# Hint: Use // for integer division and % for remainder

# %% [markdown]
# ### Challenge 4: Email Formatter
# Ask for first name, last name, and domain. Create an email address.
# Example: "John" + "Doe" + "gmail.com" → "john.doe@gmail.com"

# %%
# Write your code here

# %% [markdown]
# ### Challenge 5: Shopping Calculator with Tax
# Ask for item price and tax rate. Calculate final price with tax.

# %%
# Write your code here

# %% [markdown]
# ### Challenge 6: Initials Generator
# Ask for full name (first, middle, last), then generate initials.
# Example: "Sarah Ahmed Hassan" → "S.A.H."

# %%
# Write your code here
# Hint: Use [0] to get the first character of a string

# %% [markdown]
# ### Challenge 7: Create Your Own!
# Design your own interactive program. Be creative!

# %%
# Your creative program here!

# %% [markdown]
# ---
# ## 🎉 Congratulations!
#
# You've completed Chapter 2! You now know:
# - ✅ How to get user input with input()
# - ✅ How to convert between data types (int, float, str)
# - ✅ How to manipulate strings with various methods
# - ✅ How to write clear comments
# - ✅ How to understand and fix common errors
# - ✅ How to create interactive programs!
#
# ### Next Steps:
# - Complete Quiz 1 to test your knowledge from Chapters 1 & 2
# - Practice building more interactive programs
# - Experiment with different string methods
# - When ready, move on to Chapter 3 to learn about making decisions!
#
# ### Pro Tips:
# 💡 Always convert input() to the right type before doing calculations
#
# 💡 Use comments to explain complex logic
#
# 💡 Read error messages carefully - they're very helpful!
#
# 💡 Test your programs with different inputs
#
# ---
#
# **Happy Coding! 🚀**
